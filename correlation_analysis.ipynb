# %%
import pandas as pd
df = pd.read_csv("measurements_poverty.csv")
df.set_index("Index",  inplace=True)
df.head()
# Out:
#         Inhabitants   Percent with incomes below $5000   Percent unemployed  \
# Index
# 1            587000                               16.5                  6.2
# 2            643000                               20.5                  6.4
# 3            635000                               26.3                  9.3
# 4            692000                               16.5                  5.3
# 5           1248000                               19.2                  7.3
#
#         Murders per annum per million inhabitants
# Index
# 1                                            11.2
# 2                                            13.4
# 3                                            40.7
# 4                                             5.3
# 5                                            24.8

# %%
corr = df.corr(method ='pearson')
corr
# Out:
#                                              Inhabitants  \
#  Inhabitants                                    1.000000
#  Percent with incomes below $5000              -0.163780
#  Percent unemployed                            -0.233406
#  Murders per annum per million inhabitants     -0.067098
#
#                                              Percent with incomes below $5000  \
#  Inhabitants                                                        -0.163780
#  Percent with incomes below $5000                                    1.000000
#  Percent unemployed                                                  0.815418
#  Murders per annum per million inhabitants                           0.839778
#
#                                              Percent unemployed  \
#  Inhabitants                                          -0.233406
#  Percent with incomes below $5000                      0.815418
#  Percent unemployed                                    1.000000
# ...

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow1_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a4d777ee_930a_11ea_ab0a_1c1b0de62a5frow1_col2 {
#             background-color:  #e36c55;
#             color:  #000000;
# ...
